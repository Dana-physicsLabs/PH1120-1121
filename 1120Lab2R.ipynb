# %% [markdown]
# ## Lab 2R for 1120/1121
# Restance investigation using the WPI Jupyter hub: https://jupyterhub.wpi.edu/hub/login
# This is written in Python 3.

# %%
import matplotlib.pyplot as plt
import numpy as numpy

# %%
#Data, but with fake numbers
v = numpy.array([5,.3,1.5,3,6,10,34])
I = numpy.array([.45,.8,1.5,2,12,4,5])

# %%
plt.plot(v,I, 'ro') #uses matplotlib to plot voltage vs current
plt.ylabel('some numbers')
plt.xlabel('more numbers')
plt.title('title')
# Out:
# Text(0.5,1,'title')

# %%
m, b = numpy.polyfit(v,I,1) #If linear looks like it's the line that fits best
plt.plot(v, m*v)

plt.plot(v,I, 'ro') #uses matplotlib to plot voltage vs current
plt.ylabel('Voltage (V)')
plt.xlabel('Current (A)')
plt.title('Voltage vs Current')
print('The slope is: ',m, 'so the equation of this line is V = ',m,'*I + ',b)
#Please remember to use proper significant figures.
# Out:
# The slope is:  0.08900729421879869 so the equation of this line is V =  0.08900729421879869 *I +  2.9181948293879767
